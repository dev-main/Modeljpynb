# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import pandas
fig = plt.figure()
ax = plt.axes(projection="3d")
df = pandas.DataFrame({
'Feature':['ScalingEffect', 'ProductChange', 'DevelopmentEffort', 'HW/OperationEffort'],
'A':[0.8,0.1,0.1,0.9],
'B':[0.3,0.15,0.15,0.7],
'C':[0.4,0.2,0.15,0.6],
'D':[0.7,0.2,0.15,0.66],
'E':[0.2,0.1,0.1,0.7],
'F':[0.2,0.7,0.8,0.85],
'G':[0.3,0.8,0.6,0.1],
'H':[0.35,0.8,0.8,0.1],
'I':[0.4,0.4,0.6,0.6],
'J':[0.5,0.5,0.75,0.5],
'K':[0.25,0.3,0.8,0.45]
})
 
#display(df.A)
#display(df.iloc[:,1])#row1
#display(df.iloc[0:,1])#row1 all
#display(df.iloc[1:,1])#row1 from 1
#display(df.iloc[2:4,1])#row1 2-3
#display(df.iloc[0,1]) erste zahl
 
ax.set_xlabel(df.iloc[1,0])
ax.set_ylabel(df.iloc[2,0])
ax.set_zlabel(df.iloc[0,0])
 
ax.scatter3D(df.iloc[:,1], df.iloc[:,2],  df.iloc[:,3], c=df.iloc[:,3], cmap='hsv');
 
    


ax.text(df.iloc[0,1], df.iloc[2,1], df.iloc[3,1],  "A" , size=12, zorder=1, color='k')
ax.text(3,3, 3, '(2)' , size=12, zorder=1, color='k')
ax.text(5, 5, 5, '(3)' , size=12, zorder=1, color='k')
ax.text(6, 6, 6, '(4)' , size=12, zorder=1, color='k')
 
ax.bar3d(df.iloc[:,1], df.iloc[:,2], df.iloc[:,3], 0.1, 0.1, -df.iloc[:,3], color='g')
plt.show()
# Out:
# 0.8
