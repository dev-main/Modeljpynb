# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import pandas

fig = plt.figure(figsize=(20,10))
#ax = plt.axes(projection="3d")
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim3d(0, 1)
ax.set_ylim3d(0,1)
ax.set_zlim3d(0,1.5)

dlabel = pandas.DataFrame({
'Feature':['ScalingEffect', 'ProductChange', 'DevelopmentEffort', 'HW/OperationEffort'],
})

df = pandas.DataFrame({
'A':[0.8,0.1,0.1,0.9],  
'B':[0.3,0.15,0.15,0.7],
'C':[0.4,0.2,0.15,0.6],
'D':[0.7,0.2,0.15,0.66],
'E':[0.2,0.1,0.1,0.7],
'F':[0.2,0.7,0.8,0.85],
'G':[0.3,0.8,0.6,0.1],
'H':[0.35,0.8,0.8,0.1],
'I':[0.4,0.4,0.6,0.6],
'J':[0.5,0.5,0.75,0.5],
'K':[0.25,0.3,0.8,0.45]
})

ax.set_xlabel(dlabel.iloc[1,0])
ax.set_ylabel(dlabel.iloc[2,0])
ax.set_zlabel(dlabel.iloc[0,0])
 
ax.text(df.iloc[1,0], df.iloc[2,0], df.iloc[0,0]-0.06,  df.columns.values[0] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,1], df.iloc[2,1], df.iloc[0,1]-0.06,  df.columns.values[1] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,2], df.iloc[2,2], df.iloc[0,2]-0.06,  df.columns.values[2] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,3], df.iloc[2,3], df.iloc[0,3]-0.06,  df.columns.values[3] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,4], df.iloc[2,4], df.iloc[0,4]-0.06,  df.columns.values[4] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,5], df.iloc[2,5], df.iloc[0,5]+0.03,  df.columns.values[5] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,6], df.iloc[2,6], df.iloc[0,6]-0.06,  df.columns.values[6] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,7], df.iloc[2,7], df.iloc[0,7]-0.06,  df.columns.values[7] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,8], df.iloc[2,8], df.iloc[0,8]-0.06,  df.columns.values[8] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,9], df.iloc[2,9], df.iloc[0,9]-0.06,  df.columns.values[9] , size=16, zorder=1, color='black')
ax.text(df.iloc[1,10], df.iloc[2,10]+0.06, df.iloc[0,10]-0.1, df.columns.values[10] , size=16, zorder=1, color='black')

ax.bar3d(df.iloc[1,:], df.iloc[2,:], df.iloc[0,:], 0.02, 0.02, -df.iloc[0,:], color='white')

ax.bar3d(df.iloc[1,:]+0.01, df.iloc[2,:], df.iloc[0,:], 0.001, 0.001, df.iloc[3,:], color='green')

plt.show()
