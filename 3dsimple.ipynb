# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import pandas
fig = plt.figure()
ax = plt.axes(projection="3d")
df = pandas.DataFrame({
   'col1': ['change', 'scaling', 'buildc', 'operc'],
   'A': [1, 3, 5, 6],
   'B': [2, 3, 5, 6],
   'C': [3, 3, 5, 6]
})
 
display(df.A)
display(df.iloc[:,1])#row1
display(df.iloc[0:,1])#row1 all
display(df.iloc[1:,1])#row1 from 1
display(df.iloc[2:4,1])#row1 2-3
 
ax.set_xlabel(df.iloc[0,0])
ax.set_ylabel(df.iloc[2,0])
ax.set_zlabel(df.iloc[1,0])
 
ax.scatter3D(df.iloc[:,1], df.iloc[:,2],  df.iloc[:,3], c=df.iloc[:,3], cmap='hsv');
 
ax.text(1, 1, 1,  df.iloc[1,1] , size=12, zorder=1, color='k')
ax.text(3,3, 3, '(2)' , size=12, zorder=1, color='k')
ax.text(5, 5, 5, '(3)' , size=12, zorder=1, color='k')
ax.text(6, 6, 6, '(4)' , size=12, zorder=1, color='k')
 
ax.bar3d(df.iloc[:,1], df.iloc[:,2], df.iloc[:,3], 0.1, 0.1, -df.iloc[:,3], color='g')
plt.show()
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# Name: A, dtype: int64
# 0    1
# 1    3
# 2    5
# 3    6
# Name: A, dtype: int64
# 0    1
# 1    3
# 2    5
# 3    6
# Name: A, dtype: int64
# 1    3
# 2    5
# 3    6
# Name: A, dtype: int64
# 2    5
# 3    6
# Name: A, dtype: int64
